# %%
import os

# %%
# %cd /content/drive/MyDrive/GMBM_Model/GMBM
# Out:
# /content/drive/.shortcut-targets-by-id/1NGlEuCXzxHFeAPpO-_SYykCPHiUnp354/GMBM

# %%
os.listdir('./config_files_text_datasets/')
# Out:
# ['config_GMBM_bbc_hindi_clean.txt',
#  'config_GMBM_bbc_2096docs.txt',
#  'config_GMBM_20newsgroup_3w.txt',
#  'config_GMBM_20newsgroup.txt',
#  'config_GMBM_20newsgroup_3w_change_order.txt',
#  'config_GMBM_bbc.txt',
#  'config_GMBM_nips.txt']

# %%
# !python start.py ./config_files_text_datasets/config_GMBM_bbc_hindi_clean.txt 7
# Out:
# Streaming output truncated to the last 5000 lines.
# itertation no: 50 img no: 3429 word no: 55 total visual words in curr img: 170 sampling event
# itertation no: 50 img no: 3429 word no: 56 total visual words in curr img: 170 sampling event
# itertation no: 50 img no: 3429 word no: 57 total visual words in curr img: 170 sampling event
# itertation no: 50 img no: 3429 word no: 58 total visual words in curr img: 170 sampling event
# itertation no: 50 img no: 3429 word no: 59 total visual words in curr img: 170 sampling event
# itertation no: 50 img no: 3429 word no: 60 total visual words in curr img: 170 sampling event
# itertation no: 50 img no: 3429 word no: 61 total visual words in curr img: 170 sampling event
# itertation no: 50 img no: 3429 word no: 62 total visual words in curr img: 170 sampling event
# itertation no: 50 img no: 3429 word no: 63 total visual words in curr img: 170 sampling event
# ...
